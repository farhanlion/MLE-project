# %%
import mlflow

mlflow.set_tracking_uri("http://mlflow:5000")
run = mlflow.get_run("1b084efbdc5f4761a39844b92a5fa6e3")  # your run_id
print("Tracking store:", mlflow.get_tracking_uri())
print("Artifact location:", run.info.artifact_uri)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[1], line 4
#       1 import mlflow
#       3 mlflow.set_tracking_uri("http://mlflow:5000")
# ----> 4 run = mlflow.get_run("1b084efbdc5f4761a39844b92a5fa6e3")  # your run_id
#       5 print("Tracking store:", mlflow.get_tracking_uri())
#       6 print("Artifact location:", run.info.artifact_uri)
#
# File /usr/local/lib/python3.12/site-packages/mlflow/tracking/fluent.py:704, in get_run(run_id)
#     672 def get_run(run_id: str) -> Run:
#     673     """
#     674     Fetch the run from backend store. The resulting Run contains a collection of run metadata --
#     675     RunInfo as well as a collection of run parameters, tags, and metrics -- RunData. It also
#    (...)    702         run_id: 7472befefc754e388e8e922824a0cca5; lifecycle_stage: active
#     703     """
# --> 704     return MlflowClient().get_run(run_id)
#
# ...
