# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pprint
import pyspark
import pyspark.sql.functions as F

from pyspark.sql.functions import to_date, col
from pyspark.sql.types import StringType, IntegerType, FloatType, DateType

# %%
# Initialize SparkSession
spark = pyspark.sql.SparkSession.builder \
    .appName("dev") \
    .config("spark.driver.memory", "4g") \
    .master("local[*]") \
    .getOrCreate()
# Set log level to ERROR to hide warnings
spark.sparkContext.setLogLevel("ERROR")

# %%
from utils.gold_feature_store import create_gold_features
from datetime import datetime
from dateutil.relativedelta import relativedelta

start_date = datetime(2016, 12, 1)
end_date   = datetime(2017, 3, 1)

current = start_date
while current <= end_date:
    inference_date = current.strftime("%Y-%m-%d")
    print(f"🏗️ Creating features for {inference_date} ...")
    create_gold_features(inference_date, spark)
    current += relativedelta(months=1)

print("✅ All monthly feature stores created successfully!")
# Out:
# 🏗️ Creating features for 2016-12-01 ...
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[9], line 12
#      10     inference_date = current.strftime("%Y-%m-%d")
#      11     print(f"🏗️ Creating features for {inference_date} ...")
# ---> 12     create_gold_features(inference_date, spark)
#      13     current += relativedelta(months=1)
#      15 print("✅ All monthly feature stores created successfully!")
#
# File /app/utils/gold_feature_store.py:160, in create_gold_features(inference_date, spark, output_path)
#     152 df_transactions_filtered = df_transactions.filter(
#     153     to_date(col("transaction_date")) <= to_date(lit(inference_date))
#     154 )
#     156 # Latest transaction date and tenure_days (registration -> latest_tx)
#     158 registered_users = (registered_users
#     159     .join(df_latest_transactions, on="msno", how="left")
# --> 160     .withColumn("tenure_days",
#     161                 F.datediff(F.col("transaction_date"), F.col("registration_date")))
#     162     .na.fill({"tenure_days": 0})
#     163 )
#     165 # Auto-renew share (global up to inference_date)
#     166 auto_renew_stats = (
#     167     df_transactions_filtered
#     168     .groupBy("msno")
#    (...)    176     )
#     177 )
#
# File /usr/local/lib/python3.12/site-packages/pyspark/sql/dataframe.py:5176, in DataFrame.withColumn(self, colName, col)
#    5171 if not isinstance(col, Column):
#    5172     raise PySparkTypeError(
#    5173         error_class="NOT_COLUMN",
#    5174         message_parameters={"arg_name": "col", "arg_type": type(col).__name__},
#    5175     )
# -> 5176 return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#
# File /usr/local/lib/python3.12/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column or function parameter with name `registration_date` cannot be resolved. Did you mean one of the following? [`transaction_date`, `max_transaction_date`, `last_play_date`, `registered_via_oh`, `transaction_id`].;
# 'Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, engagement_ratio_7_30#1524, last_play_date#1546, days_since_last_play#1571, trend_secs_w30#1730, payment_method_id#1233, payment_plan_days#1234, plan_list_price#1235, actual_amount_paid#1236, is_auto_renew#1237, transaction_date#1238, membership_expire_date#1239, is_cancel#1240, source_file#1241, day#1242, transaction_id#1243, year#1244, ... 4 more fields]
# +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, engagement_ratio_7_30#1524, last_play_date#1546, days_since_last_play#1571, trend_secs_w30#1730, payment_method_id#1233, payment_plan_days#1234, plan_list_price#1235, actual_amount_paid#1236, is_auto_renew#1237, transaction_date#1238, membership_expire_date#1239, is_cancel#1240, source_file#1241, day#1242, transaction_id#1243, year#1244, ... 3 more fields]
#    +- Join LeftOuter, (msno#1264 = msno#1232)
#       :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, engagement_ratio_7_30#1524, last_play_date#1546, days_since_last_play#1571, coalesce(nanvl(trend_secs_w30#1627, cast(null as double)), cast(0.0 as double)) AS trend_secs_w30#1730]
#       :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, engagement_ratio_7_30#1524, last_play_date#1546, days_since_last_play#1571, trend_secs_w30#1627]
#       :     +- Join LeftOuter, (msno#1264 = msno#1694)
#       :        :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, engagement_ratio_7_30#1524, last_play_date#1546, datediff(to_date(2016-12-01, None, Some(Etc/UTC), false), last_play_date#1546) AS days_since_last_play#1571]
#       :        :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, engagement_ratio_7_30#1524, last_play_date#1546]
#       :        :     +- Join LeftOuter, (msno#1264 = msno#1549)
#       :        :        :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1515, (sum_secs_w7#1515 / CASE WHEN (sum_secs_w30#1370 > cast(0 as double)) THEN sum_secs_w30#1370 ELSE 1.0 END) AS engagement_ratio_7_30#1524]
#       :        :        :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, coalesce(nanvl(sum_secs_w7#1484, cast(null as double)), cast(0.0 as double)) AS sum_secs_w7#1515]
#       :        :        :     +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1464, sum_secs_w7#1484]
#       :        :        :        +- Join LeftOuter, (msno#1264 = msno#1487)
#       :        :        :           :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, coalesce(nanvl(complete_rate_w30#1435, cast(null as double)), cast(0.0 as double)) AS complete_rate_w30#1464]
#       :        :        :           :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1415L, complete_rate_w30#1435]
#       :        :        :           :     +- Join LeftOuter, (msno#1264 = msno#1438)
#       :        :        :           :        :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, coalesce(active_days_w30#1387L, cast(0 as bigint)) AS active_days_w30#1415L]
#       :        :        :           :        :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1370, active_days_w30#1387L]
#       :        :        :           :        :     +- Join LeftOuter, (msno#1264 = msno#1391)
#       :        :        :           :        :        :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, coalesce(nanvl(sum_secs_w30#1357, cast(null as double)), cast(0.0 as double)) AS sum_secs_w30#1370]
#       :        :        :           :        :        :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321, sum_secs_w30#1357]
#       :        :        :           :        :        :     +- Join LeftOuter, (msno#1264 = msno#1182)
#       :        :        :           :        :        :        :- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via_oh#1315, city_clean_oh#1321]
#       :        :        :           :        :        :        :  +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via#1266, city_clean#1265, registered_via_oh#1315, CASE WHEN isnull(city_clean#1265) THEN cast(0 as string) ELSE city_clean#1265 END AS city_clean_oh#1321]
#       :        :        :           :        :        :        :     +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via#1266, city_clean#1265, CASE WHEN isnull(registered_via#1266) THEN cast(0 as string) ELSE registered_via#1266 END AS registered_via_oh#1315]
#       :        :        :           :        :        :        :        +- Project [msno#1264, tenure_days_at_snapshot#1299, registered_via#1266, city_clean#1265]
#       :        :        :           :        :        :        :           +- Project [msno#1264, city_clean#1265, registered_via#1266, registration_date#1286, datediff(to_date(2016-12-01, None, Some(Etc/UTC), false), registration_date#1286) AS tenure_days_at_snapshot#1299, registered_via_freq#1269, city_freq#1270, city_idx#1271, via_idx#1272, city_oh#1273, via_oh#1274]
#       :        :        :           :        :        :        :              +- Filter (registration_date#1286 <= to_date(2016-12-01, None, Some(Etc/UTC), false))
#       :        :        :           :        :        :        :                 +- Project [msno#1264, city_clean#1265, registered_via#1266, to_date(registration_date#1267, None, Some(Etc/UTC), false) AS registration_date#1286, tenure_days_at_snapshot#1268, registered_via_freq#1269, city_freq#1270, city_idx#1271, via_idx#1272, city_oh#1273, via_oh#1274]
#       :        :        :           :        :        :        :                    +- Relation [msno#1264,city_clean#1265,registered_via#1266,registration_date#1267,tenure_days_at_snapshot#1268,registered_via_freq#1269,city_freq#1270,city_idx#1271,via_idx#1272,city_oh#1273,via_oh#1274] parquet
#       :        :        :           :        :        :        +- Aggregate [msno#1182], [msno#1182, sum(total_secs#1190) AS sum_secs_w30#1357]
#       :        :        :           :        :        :           +- Filter ((date#1332 >= date_sub(to_date(2016-12-01, None, Some(Etc/UTC), false), 29)) AND (date#1332 <= to_date(2016-12-01, None, Some(Etc/UTC), false)))
#       :        :        :           :        :        :              +- Project [msno#1182, to_date(date#1183, None, Some(Etc/UTC), false) AS date#1332, num_25#1184, num_50#1185, num_75#1186, num_985#1187, num_100#1188, num_unq#1189, total_secs#1190, year#1191, month#1192]
#       :        :        :           :        :        :                 +- Relation [msno#1182,date#1183,num_25#1184,num_50#1185,num_75#1186,num_985#1187,num_100#1188,num_unq#1189,total_secs#1190,year#1191,month#1192] parquet
#       :        :        :           :        :        +- Aggregate [msno#1391], [msno#1391, count(distinct date#1332) AS active_days_w30#1387L]
#       :        :        :           :        :           +- Filter ((date#1332 >= date_sub(to_date(2016-12-01, None, Some(Etc/UTC), false), 29)) AND (date#1332 <= to_date(2016-12-01, None, Some(Etc/UTC), false)))
#       :        :        :           :        :              +- Project [msno#1391, to_date(date#1392, None, Some(Etc/UTC), false) AS date#1332, num_25#1393, num_50#1394, num_75#1395, num_985#1396, num_100#1397, num_unq#1398, total_secs#1399, year#1400, month#1401]
#       :        :        :           :        :                 +- Relation [msno#1391,date#1392,num_25#1393,num_50#1394,num_75#1395,num_985#1396,num_100#1397,num_unq#1398,total_secs#1399,year#1400,month#1401] parquet
#       :        :        :           :        +- Aggregate [msno#1438], [msno#1438, (cast(sum(num_100#1444) as double) / cast(sum(num_unq#1445) as double)) AS complete_rate_w30#1435]
#       :        :        :           :           +- Filter ((date#1332 >= date_sub(to_date(2016-12-01, None, Some(Etc/UTC), false), 29)) AND (date#1332 <= to_date(2016-12-01, None, Some(Etc/UTC), false)))
#       :        :        :           :              +- Project [msno#1438, to_date(date#1439, None, Some(Etc/UTC), false) AS date#1332, num_25#1440, num_50#1441, num_75#1442, num_985#1443, num_100#1444, num_unq#1445, total_secs#1446, year#1447, month#1448]
#       :        :        :           :                 +- Relation [msno#1438,date#1439,num_25#1440,num_50#1441,num_75#1442,num_985#1443,num_100#1444,num_unq#1445,total_secs#1446,year#1447,month#1448] parquet
#       :        :        :           +- Aggregate [msno#1487], [msno#1487, sum(total_secs#1495) AS sum_secs_w7#1484]
#       :        :        :              +- Filter ((date#1332 >= date_sub(to_date(2016-12-01, None, Some(Etc/UTC), false), 6)) AND (date#1332 <= to_date(2016-12-01, None, Some(Etc/UTC), false)))
#       :        :        :                 +- Project [msno#1487, to_date(date#1488, None, Some(Etc/UTC), false) AS date#1332, num_25#1489, num_50#1490, num_75#1491, num_985#1492, num_100#1493, num_unq#1494, total_secs#1495, year#1496, month#1497]
#       :        :        :                    +- Relation [msno#1487,date#1488,num_25#1489,num_50#1490,num_75#1491,num_985#1492,num_100#1493,num_unq#1494,total_secs#1495,year#1496,month#1497] parquet
#       :        :        +- Aggregate [msno#1549], [msno#1549, max(date#1332) AS last_play_date#1546]
#       :        :           +- Filter (date#1332 <= to_date(2016-12-01, None, Some(Etc/UTC), false))
#       :        :              +- Project [msno#1549, to_date(date#1550, None, Some(Etc/UTC), false) AS date#1332, num_25#1551, num_50#1552, num_75#1553, num_985#1554, num_100#1555, num_unq#1556, total_secs#1557, year#1558, month#1559]
#       :        :                 +- Relation [msno#1549,date#1550,num_25#1551,num_50#1552,num_75#1553,num_985#1554,num_100#1555,num_unq#1556,total_secs#1557,year#1558,month#1559] parquet
#       :        +- Aggregate [msno#1694], [msno#1694, (covar_pop(cast(day_idx#1600 as double), daily_secs#1595) / var_pop(cast(day_idx#1600 as double))) AS trend_secs_w30#1627]
#       :           +- Project [msno#1694, date#1332, daily_secs#1595, day_idx#1600]
#       :              +- Project [msno#1694, date#1332, daily_secs#1595, day_idx#1600, day_idx#1600]
#       :                 +- Window [row_number() windowspecdefinition(msno#1694, date#1332 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS day_idx#1600], [msno#1694], [date#1332 ASC NULLS FIRST]
#       :                    +- Project [msno#1694, date#1332, daily_secs#1595]
#       :                       +- Aggregate [msno#1694, date#1332], [msno#1694, date#1332, sum(total_secs#1702) AS daily_secs#1595]
#       :                          +- Filter ((date#1332 >= date_sub(to_date(2016-12-01, None, Some(Etc/UTC), false), 29)) AND (date#1332 <= to_date(2016-12-01, None, Some(Etc/UTC), false)))
#       :                             +- Project [msno#1694, to_date(date#1695, None, Some(Etc/UTC), false) AS date#1332, num_25#1696, num_50#1697, num_75#1698, num_985#1699, num_100#1700, num_unq#1701, total_secs#1702, year#1703, month#1704]
#       :                                +- Relation [msno#1694,date#1695,num_25#1696,num_50#1697,num_75#1698,num_985#1699,num_100#1700,num_unq#1701,total_secs#1702,year#1703,month#1704] parquet
#       +- Relation [msno#1232,payment_method_id#1233,payment_plan_days#1234,plan_list_price#1235,actual_amount_paid#1236,is_auto_renew#1237,transaction_date#1238,membership_expire_date#1239,is_cancel#1240,source_file#1241,day#1242,transaction_id#1243,year#1244,month#1245,total_plan_days#1246,max_transaction_date#1247] parquet
